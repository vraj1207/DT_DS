# %% [markdown]
# # PROJECT-4 (EMPLOYEES SALARY PROJECT)

# %%
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('1000 Records.csv')
df.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 4     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# ...

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Name Prefix             1000 non-null   object
#  2   First Name              1000 non-null   object
#  3   Middle Initial          1000 non-null   object
#  4   Last Name               1000 non-null   object
#  5   Gender                  1000 non-null   object
#  6   E Mail                  1000 non-null   object
#  7   Father's Name           1000 non-null   object
#  8   Mother's Name           1000 non-null   object
#  9   Mother's Maiden Name    1000 non-null   object
#  10  Date of Birth           1000 non-null   object
#  11  Time of Birth           1000 non-null   object
#  12  Age in Yrs.             1000 non-null   float64
#  13  Weight in Kgs.          1000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Emp ID                    0
# Name Prefix               0
# First Name                0
# Middle Initial            0
# Last Name                 0
# Gender                    0
# E Mail                    0
# Father's Name             0
# Mother's Name             0
# Mother's Maiden Name      0
# Date of Birth             0
# Time of Birth             0
# Age in Yrs.               0
# Weight in Kgs.            0
# Date of Joining           0
# Quarter of Joining        0
# Half of Joining           0
# Year of Joining           0
# Month of Joining          0
# Month Name of Joining     0
# Short Month               0
# Day of Joining            0
# DOW of Joining            0
# Short DOW                 0
# Age in Company (Years)    0
# Salary                    0
# Last % Hike               0
# SSN                       0
# Phone No.                 0
# Place Name                0
# County                    0
# City                      0
# State                     0
# ...

# %%
import seaborn as sns
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#               Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count    1000.000000  1000.000000     1000.000000      1000.000000
# mean   549097.583000    40.377250       59.409000      2006.992000
# std    264810.879315    11.107729       13.900322         8.565588
# min    114425.000000    21.040000       40.000000      1980.000000
# 25%    307757.000000    30.925000       49.000000      2002.000000
# 50%    543073.000000    40.730000       57.000000      2009.000000
# 75%    788450.250000    49.852500       68.000000      2014.000000
# max    999475.000000    59.980000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       1000.000000     1000.000000             1000.000000
# mean           6.415000       16.481000               10.093720
# std            3.428488        8.831514                8.568863
# min            1.000000        1.000000                0.000000
# ...

# %%
df.shape
# Out:
# (1000, 37)

# %%
df.dtypes
# Out:
# Emp ID                      int64
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# ...

# %%
dfcor = df.corr()
sns.heatmap(dfcor,annot=True,fmt='.1g')

# %%
df.sample()
# Out:
#      Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 660  161109        Hon.     Kareem              R   Fuentes      M
#
#                          E Mail  Father's Name    Mother's Name  \
# 660  kareem.fuentes@hotmail.com  Caleb Fuentes  Pauline Fuentes
#
#     Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 660                 Owen  ...  183-86-8752  202-469-0012  Washington
#
#                    County        City State    Zip  Region  User Name  \
# 660  District of Columbia  Washington    DC  20099   South  krfuentes
#
#      Password
# 660  Z#\J@]9|
#
# [1 rows x 37 columns]

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent_1 = df.isnull().sum()/df.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data
# Out:
#                         Total    %
# Password                    0  0.0
# Year of Joining             0  0.0
# Quarter of Joining          0  0.0
# Date of Joining             0  0.0
# Weight in Kgs.              0  0.0
# Age in Yrs.                 0  0.0
# Time of Birth               0  0.0
# Date of Birth               0  0.0
# Mother's Maiden Name        0  0.0
# Mother's Name               0  0.0
# Father's Name               0  0.0
# E Mail                      0  0.0
# Gender                      0  0.0
# Last Name                   0  0.0
# Middle Initial              0  0.0
# First Name                  0  0.0
# Name Prefix                 0  0.0
# Half of Joining             0  0.0
# Month of Joining            0  0.0
# User Name                   0  0.0
# Month Name of Joining       0  0.0
# Region                      0  0.0
# Zip                         0  0.0
# State                       0  0.0
# City                        0  0.0
# County                      0  0.0
# ...

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df['Date of Birth'] = pd.to_datetime(df['Date of Birth']).dt.strftime("%Y%m%d")

# %%
df['Date of Joining'] = pd.to_datetime(df['Date of Joining']).dt.strftime("%Y%m%d")

# %%
df.head(2)
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  850297         Ms.     Shawna              W      Buck      F
# 1  304721         Mr.  Nathaniel              Z     Burke      M
#
#                         E Mail  Father's Name Mother's Name  \
# 0        shawna.buck@gmail.com   Rosario Buck   Keisha Buck
# 1  nathaniel.burke@walmart.com  Derrick Burke  Phoebe Burke
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  County  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas   Clark
# 1                 Pugh  ...  550-99-9897  231-765-6923       Irons    Lake
#
#         City State    Zip   Region  User Name         Password
# 0  Las Vegas    NV  89128     West     swbuck  ja8?k3BTF^]o@<&
# 1      Irons    MI  49644  Midwest    nzburke   tPA@4Wh9Ja$+Ln
#
# [2 rows x 37 columns]

# %%
df1 = df.iloc[:, [5,12,13,24,26,25]]
df1
# Out:
#     Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years) Last % Hike  \
# 0        F        45.66              44                    6.61         17%
# 1        M        23.76              52                    0.26         14%
# 2        F        22.68              42                    0.34         28%
# 3        F        41.70              43                   14.43         16%
# 4        F        22.39              58                    0.79         11%
# ..     ...          ...             ...                     ...         ...
# 995      F        32.01              59                    9.56         10%
# 996      M        30.48              84                    7.40         16%
# 997      F        59.88              50                   16.44         14%
# 998      F        30.21              48                    5.37          9%
# 999      F        59.78              56                   37.55          6%
#
#      Salary
# 0    119090
# 1    117991
# 2    161045
# ...

# %%
df1['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
port = {"F":0,"M":1}
df1['Gender'] = df1['Gender'].map(port)

# %%
df1.head()
# Out:
#    Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years) Last % Hike  \
# 0       0        45.66              44                    6.61         17%
# 1       1        23.76              52                    0.26         14%
# 2       0        22.68              42                    0.34         28%
# 3       0        41.70              43                   14.43         16%
# 4       0        22.39              58                    0.79         11%
#
#    Salary
# 0  119090
# 1  117991
# 2  161045
# 3  142616
# 4  135706

# %%
df1['Salary']=df1['Salary'].astype(float)

# %%
df1['Last % Hike'] = list(map(lambda x: x[:-1], df1['Last % Hike'].values))

df1['Last % Hike'] = [float(x) for x in df1['Last % Hike'].values]

df1.head(1)
# Out:
#    Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years)  Last % Hike  \
# 0       0        45.66              44                    6.61         17.0
#
#      Salary
# 0  119090.0

# %%
df1cor = df1.corr()
df1cor
# Out:
#                           Gender  Age in Yrs.  Weight in Kgs.  \
# Gender                  1.000000    -0.013794        0.713811
# Age in Yrs.            -0.013794     1.000000       -0.065656
# Weight in Kgs.          0.713811    -0.065656        1.000000
# Age in Company (Years) -0.047735     0.676408       -0.058846
# Last % Hike             0.030573    -0.030761        0.015563
# Salary                  0.050883     0.041422        0.061088
#
#                         Age in Company (Years)  Last % Hike    Salary
# Gender                               -0.047735     0.030573  0.050883
# Age in Yrs.                           0.676408    -0.030761  0.041422
# Weight in Kgs.                       -0.058846     0.015563  0.061088
# Age in Company (Years)                1.000000    -0.008238  0.054212
# Last % Hike                          -0.008238     1.000000 -0.005366
# Salary                                0.054212    -0.005366  1.000000

# %%
dfcor = df.corr()
dfcor
# Out:
#                           Emp ID  Age in Yrs.  Weight in Kgs.  \
# Emp ID                  1.000000    -0.028516        0.028175
# Age in Yrs.            -0.028516     1.000000       -0.065656
# Weight in Kgs.          0.028175    -0.065656        1.000000
# Year of Joining         0.039009    -0.676875        0.058794
# Month of Joining        0.000999     0.022617        0.003933
# Day of Joining          0.006178    -0.026387       -0.038591
# Age in Company (Years) -0.039064     0.676408       -0.058846
# Salary                 -0.027248     0.041422        0.061088
# Zip                     0.020033    -0.017266       -0.021019
#
#                         Year of Joining  Month of Joining  Day of Joining  \
# Emp ID                         0.039009          0.000999        0.006178
# Age in Yrs.                   -0.676875          0.022617       -0.026387
# Weight in Kgs.                 0.058794          0.003933       -0.038591
# ...

# %%
df1
# Out:
#      Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years)  Last % Hike  \
# 0         0        45.66              44                    6.61         17.0
# 1         1        23.76              52                    0.26         14.0
# 2         0        22.68              42                    0.34         28.0
# 3         0        41.70              43                   14.43         16.0
# 4         0        22.39              58                    0.79         11.0
# ..      ...          ...             ...                     ...          ...
# 995       0        32.01              59                    9.56         10.0
# 996       1        30.48              84                    7.40         16.0
# 997       0        59.88              50                   16.44         14.0
# 998       0        30.21              48                    5.37          9.0
# 999       0        59.78              56                   37.55          6.0
#
#        Salary
# 0    119090.0
# ...

# %%
sns.heatmap(df1cor,annot = True)

# %% [markdown]
# # EDA

# %% [raw]
# Univariate Analysis

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(df1['Age in Yrs.'])
plt.title("Age")
plt.show()

# %%
sns.distplot(df1['Salary'])
plt.title("Salary")
plt.show()

# %%
sns.countplot(df1['Gender'])
plt.title("Gender")
plt.show()

# %% [raw]
# Bivariate Analysis

# %%
# Plotting scatterplot to show relationship between age and salary

plt.scatter(df1['Age in Yrs.'],df1['Salary'])
plt.title("Scatter_Plot")
plt.xlabel("Age in Yrs.")
plt.ylabel("Salary")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Q:- Why the structure like this, What is is showing positive relation or nagative i am confused.

# %% [raw]
# Multivariate Analysis

# %%
df2cor = df1.corr()
sns.heatmap(df2cor,annot=True,fmt='.1g')

# %%
df1['Gender'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Gender, dtype: int64

# %% [markdown]
# # Handling Outliers

# %%
sns.boxplot(data =df1['Salary'],orient = "h",palette = "Set2")
plt.title("Outlier detection")
plt.show()

# %%
df1.shape
# Out:
# (1000, 6)

# %%
collist = df1.columns.values
ncol=15
nrows=10

# %%
df1.dtypes
# Out:
# Gender                      int64
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Age in Company (Years)    float64
# Last % Hike               float64
# Salary                    float64
# dtype: object

# %%
df1.sample()
# Out:
#      Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years)  Last % Hike  \
# 793       1        45.28              86                   19.97         10.0
#
#        Salary
# 793  129888.0

# %%
df1.shape
# Out:
# (1000, 6)

# %%
df1.dtypes
# Out:
# Gender                      int64
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Age in Company (Years)    float64
# Last % Hike               float64
# Salary                    float64
# dtype: object

# %%
plt.figure(figsize = (ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df1[collist[i]],color ='green',orient='v')

# %%
from scipy.stats import zscore
z= np.abs(zscore(df1))
threshold =3
new_df = df1[(z<3).all(axis=1)]

# %%
print("Original Shape = ",df1.shape,"\nNew Shape= ",new_df.shape)
# Out:
# Original Shape =  (1000, 6)
# New Shape=  (996, 6)

# %% [markdown]
# # Skewness

# %%
#Checking the skewness 

new_df.skew()
# Out:
# Gender                   -0.040229
# Age in Yrs.               0.008064
# Weight in Kgs.            0.653638
# Age in Company (Years)    0.933414
# Last % Hike              -0.091561
# Salary                    0.034012
# dtype: float64

# %%
new_df.shape
# Out:
# (996, 6)

# %%
x= new_df.iloc[:,:-1]
x
# Out:
#      Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years)  Last % Hike
# 0         0        45.66              44                    6.61         17.0
# 1         1        23.76              52                    0.26         14.0
# 2         0        22.68              42                    0.34         28.0
# 3         0        41.70              43                   14.43         16.0
# 4         0        22.39              58                    0.79         11.0
# ..      ...          ...             ...                     ...          ...
# 994       1        28.61              73                    0.10          7.0
# 995       0        32.01              59                    9.56         10.0
# 996       1        30.48              84                    7.40         16.0
# 997       0        59.88              50                   16.44         14.0
# 998       0        30.21              48                    5.37          9.0
#
# [996 rows x 5 columns]

# %%
new_df.dtypes
# Out:
# Gender                      int64
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Age in Company (Years)    float64
# Last % Hike               float64
# Salary                    float64
# dtype: object

# %%
np.any(np.isnan(new_df))
# Out:
# False

# %%
np.all(np.isfinite(new_df))
# Out:
# True

# %%
df_new = new_df.replace([np.inf, -np.inf], np.nan)

# %%
df_new.shape
# Out:
# (996, 6)

# %%
df_new.head(2)
# Out:
#    Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years)  Last % Hike  \
# 0       0        45.66              44                    6.61         17.0
# 1       1        23.76              52                    0.26         14.0
#
#      Salary
# 0  119090.0
# 1  117991.0

# %%
x.head(2)
# Out:
#    Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years)  Last % Hike
# 0       0        45.66              44                    6.61         17.0
# 1       1        23.76              52                    0.26         14.0

# %%
new_df.replace([np.inf, -np.inf], np.nan).dropna(axis=1)
# Out:
#      Gender  Age in Yrs.  Weight in Kgs.  Age in Company (Years)  Last % Hike  \
# 0         0        45.66              44                    6.61         17.0
# 1         1        23.76              52                    0.26         14.0
# 2         0        22.68              42                    0.34         28.0
# 3         0        41.70              43                   14.43         16.0
# 4         0        22.39              58                    0.79         11.0
# ..      ...          ...             ...                     ...          ...
# 994       1        28.61              73                    0.10          7.0
# 995       0        32.01              59                    9.56         10.0
# 996       1        30.48              84                    7.40         16.0
# 997       0        59.88              50                   16.44         14.0
# 998       0        30.21              48                    5.37          9.0
#
#        Salary
# 0    119090.0
# ...

# %% [markdown]
# # Preparing Dataset For Model Training

# %%
x = new_df.drop("Salary",axis=1)
y = new_df["Salary"]

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method = 'yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaledX = sc.fit_transform(x)

# %%
#Finding Best Random State

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

best_rstate=0
accu=0

for i in range(30,200):
    x_train,x_test,y_train,y_test = train_test_split(scaledX,y,test_size = .25,random_state=i)
    mod = LinearRegression()
    mod.fit(x_train,y_train)
    y_pred = mod.predict(x_test)
    tempaccu = r2_score(y_test,y_pred)
    
    if tempaccu>accu:
        accu = tempaccu
        best_rstate = i
        
        
        
print(f"Best Accuracy {accu*100} found on random_state {best_rstate}")
# Out:
# Best Accuracy 1.7534856140210442 found on random_state 118

# %%
#Creating train test split using best random state

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(scaledX,y,test_size = .25 ,random_state = 118)

# %% [markdown]
# # Finding Best Model

# %% [raw]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
y_pred = LR.predict(x_test)
r2score = r2_score(y_test,y_pred)
cvscore = cross_val_score(LinearRegression(),x_train,y_train,cv=5).mean()
print(f"Accuracy = {r2score*100},Cross_val_score={cvscore*100} & difference = {(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy = 1.7534856140210442,Cross_val_score=-2.2698462509366113 & difference = 4.0233318649576555

# %% [raw]
# RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor()
RF.fit(x_train,y_train)
y_pred = RF.predict(x_test)
r2score = r2_score(y_test,y_pred)
cvscore = cross_val_score(RandomForestRegressor(),x_train,y_train,cv=5).mean()
print(f"Accuracy = {r2score*100},Cross_val_score={cvscore*100} & difference = {(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy = -15.95496943233885,Cross_val_score=-19.73932126639559 & difference = 3.7843518340567392

# %% [raw]
# AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ADB = AdaBoostRegressor()
ADB.fit(x_train,y_train)
y_pred = ADB.predict(x_test)
r2score = r2_score(y_test,y_pred)
cvscore = cross_val_score(AdaBoostRegressor(),x_train,y_train,cv=5).mean()
print(f"Accuracy = {r2score*100},Cross_val_score={cvscore*100} & difference = {(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy = -0.6201308495734192,Cross_val_score=-3.216380597962263 & difference = 2.5962497483888436

# %% [raw]
# SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor
SGD = SGDRegressor()
SGD.fit(x_train,y_train)
y_pred = SGD.predict(x_test)
r2score = r2_score(y_test,y_pred)
cvscore = cross_val_score(SGDRegressor(),x_train,y_train,cv=5).mean()
print(f"Accuracy = {r2score*100},Cross_val_score={cvscore*100} & difference = {(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy = 1.7871101888355945,Cross_val_score=-2.0496602321125224 & difference = 3.836770420948117

# %% [markdown]
# # Hyperparameter Tuning

# %%
parameters = {"max_iter": [500,700,900,1100,1200,1300,1400,1500],
              "alpha" :[0.0001,0.001,0.01,0.1,1,10,100],
               "penalty": ["elasticnet","l1","l2"]}

# %%
from sklearn.model_selection import GridSearchCV

GCV = GridSearchCV(SGDRegressor(),parameters,cv=5,scoring = 'r2')
GCV.fit(x_train,y_train)
GCV.best_estimator_
GCV_pred = GCV.best_estimator_.predict(x_test)
print("Final Accuracy :",r2_score(y_test,GCV_pred)*100)
# Out:
# Final Accuracy : 0.3152502197462437

# %%
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred=lg.predict(x_test)
print(pred)
# Out:
# [ 45969. 171987. 126933.  88456. 136817. 184073. 154559. 118525.  98023.
#   90653. 193651. 196480. 194639. 144104. 151869. 178822. 173372. 136817.
#  173372.  87760. 118525. 112711. 180468. 173372. 164512.  62401. 173372.
#  173372.  91068. 116847. 155291. 126933. 102819. 136817. 173372.  62973.
#   61487. 139476.  46179.  46179.  55042. 126933. 128144. 183713. 173372.
#   55341. 154559. 173372. 190560. 136817. 136817.  61082. 118525. 193315.
#   80934. 154216.  55341. 118525.  93417.  47356. 136817. 136097. 136817.
#  178822. 138006. 113482. 116818.  54302. 154559.  91453. 117985. 150578.
#   83325.  87760. 143127. 136817. 185105. 173178. 196782.  61082. 156203.
#  102819.  83325. 105054. 113482. 154559. 136817. 136817. 117991. 146938.
#   98023.  66575. 154559.  98030.  75123. 176179.  93228.  59439. 193315.
#  169631. 120192.  62888. 126933.  96974. 176707.  68295.  62973. 111183.
#  173372. 136817.  68295.  91453.  59439. 118525. 128144.  47971. 103726.
# ...

# %%
from sklearn.metrics import accuracy_score
print("accuracy_score: ",accuracy_score(y_test,pred))
# Out:
# accuracy_score:  0.0

# %% [markdown]
# # Q - I am sp confused why the accuracy score is so low. As per my understanding the data is very less corelated to the target variable , am i right?
