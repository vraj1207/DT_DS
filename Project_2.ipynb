# %% [markdown]
# # WineData Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Winedataset.csv")
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  diluted wines  Proline
# 0             5.64  1.04           3.92         1065
# 1             4.38  1.05           3.40         1050
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# diluted wines           float64
# Proline                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  diluted wines         178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [markdown]
# Key Observation:-
#
#     1. Standard Deviation is high in Magnesium and Proline columns.
#     2. In some observation mean is higher than median like Malic acid, Magnesium and prolin. So may be in this columns skewnees        present.
#     3. Also Alacalinity of ash, Magnesium,Color Intensity and proline the difference between 75 percentile and maximum is high.
#     4. By above observations we can say that there are outliers present in 2 or  3 columns.

# %% [raw]
# Exploring Data Variable

# %%
df.Class.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %% [markdown]
# Target/Dependent variable is discrete and categorical in nature.

# %%
df.Class.value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Dataset has no missing value

# %% [markdown]
# # Corelation

# %%
dfcor = df.corr()
dfcor
# Out:
#                          Class   Alcohol  Malic acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# diluted wines        -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
sns.heatmap(dfcor)

# %%
sns.heatmap(dfcor,annot = True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %% [markdown]
#  Total phenols,Flavanoids,Hue,diluted wines and proline are highly negatively corelated with target data.

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %% [raw]
# Outliers Detection

# %%
df['Magnesium'].plot.box()

# %%
df['Proline    '].plot.box()

# %%
df['Alcalinity of ash'].plot.box()

# %%
df['Color intensity'].plot.box()

# %%
df.shape
# Out:
# (178, 14)

# %%
collist = df.columns.values
ncol=14
nrows=10

# %%
plt.figure(figsize = (ncol,5*ncol))

for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color = 'green',orient='v')
    plt.tight_layout()

# %% [raw]
# Check Distribution of skewness

# %%
plt.figure(figsize = (16,16))

for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %% [markdown]
# Positive skewness present in independent variables

# %% [markdown]
# # Data Cleaaning

# %%
#Droping highly negative corelated columns

df.drop(['Total phenols','Flavanoids','Hue','diluted wines','Proline    '],axis=1,inplace =True)
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Nonflavanoid phenols  Proanthocyanins  Color intensity
# 0                  0.28             2.29             5.64
# 1                  0.26             1.28             4.38
# 2                  0.30             2.81             5.68
# 3                  0.24             2.18             7.80
# 4                  0.39             1.82             4.32

# %%
df.shape
# Out:
# (178, 9)

# %% [raw]
# Removing Outliers

# %%
from scipy.stats import zscore
z= np.abs(zscore(df))
threshold =3
np.where(z>3)
# Out:
# (array([ 25,  59,  69,  73,  95, 110, 121, 123, 158], dtype=int64),
#  array([3, 3, 5, 4, 5, 7, 3, 2, 8], dtype=int64))

# %%
df_new = df[(z<3).all(axis=1)]
df_new
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Nonflavanoid phenols  Proanthocyanins  Color intensity
# 0                    0.28             2.29             5.64
# ...

# %%
df.shape
# Out:
# (178, 9)

# %%
#Percentage Loss of data after removing outliers
percentage_loss=((9)/178)*100
percentage_loss
# Out:
# 5.056179775280898

# %%
#IQR Method

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# Class                    2.0000
# Alcohol                  1.3150
# Malic acid               1.4800
# Ash                      0.3475
# Alcalinity of ash        4.3000
# Magnesium               19.0000
# Nonflavanoid phenols     0.1675
# Proanthocyanins          0.7000
# Color intensity          2.9800
# dtype: float64

# %%
df_new1 = df[~((df<(Q1-1.5*IQR)) | (df > (Q3+1.5*IQR))).any(axis=1)]
print(df_new.shape)
# Out:
# (169, 9)

# %% [markdown]
# So Percentage loss of data by Zscore and IQR method are same so we can proceed with any one of them. I am proceeding with zscore

# %%
df_new.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Nonflavanoid phenols  Proanthocyanins  Color intensity
# 0                  0.28             2.29             5.64
# 1                  0.26             1.28             4.38
# 2                  0.30             2.81             5.68
# 3                  0.24             2.18             7.80
# 4                  0.39             1.82             4.32

# %%
x= df_new.iloc[:,1:]
x
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      14.23        1.71  2.43               15.6        127
# 1      13.20        1.78  2.14               11.2        100
# 2      13.16        2.36  2.67               18.6        101
# 3      14.37        1.95  2.50               16.8        113
# 4      13.24        2.59  2.87               21.0        118
# ..       ...         ...   ...                ...        ...
# 173    13.71        5.65  2.45               20.5         95
# 174    13.40        3.91  2.48               23.0        102
# 175    13.27        4.28  2.26               20.0        120
# 176    13.17        2.59  2.37               20.0        120
# 177    14.13        4.10  2.74               24.5         96
#
#      Nonflavanoid phenols  Proanthocyanins  Color intensity
# 0                    0.28             2.29             5.64
# 1                    0.26             1.28             4.38
# ...

# %%
y = df_new.iloc[:,0]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Class, Length: 169, dtype: int64

# %% [raw]
# Removing Skewness

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method = 'yeo-johnson')

# %% [markdown]
# # Model Selection_ Classification

# %%
import pandas as pd
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
x
# Out:
# array([[ 1.53583456, -0.42712342,  0.22348445, ..., -0.61871108,
#          1.34816542,  0.4148329 ],
#        [ 0.20048696, -0.32658578, -0.95464335, ..., -0.82356782,
#         -0.47859481, -0.16148036],
#        [ 0.15012789,  0.33733158,  1.2756847 , ..., -0.42345684,
#          2.15891663,  0.43128351],
#        ...,
#        [ 0.28891101,  1.48587419, -0.47972192, ...,  0.64366838,
#         -0.33821018,  1.84588041],
#        [ 0.16270598,  0.53875878, -0.02862229, ...,  1.28360133,
#         -0.12248571,  1.61676059],
#        [ 1.40316878,  1.41392284,  1.59620237, ...,  1.45263869,
#         -0.33821018,  1.59007087]])

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Class, Length: 169, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .22,random_state =42)

# %%
#mnb = MultinomialNB()
#mnb.fit(x_train,y_train)
#predmnb = mnb.predict(x_test)
#print(accuracy_score(y_test,predmnb))
#print(confusion_matrix(y_test,predmnb))
#print(classification_report(y_test,predmnb))

# %% [markdown]
# Question - Why the error comes in MultinomialNB when i have -ve values in X, How to deal?

# %%
svc = SVC(kernel = 'rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 1.0
# [[16  0  0]
#  [ 0 14  0]
#  [ 0  0  8]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        14
#            3       1.00      1.00      1.00         8
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc = dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.868421052631579
# [[14  1  1]
#  [ 1 12  1]
#  [ 1  0  7]]
#               precision    recall  f1-score   support
#
#            1       0.88      0.88      0.88        16
#            2       0.92      0.86      0.89        14
#            3       0.78      0.88      0.82         8
#
#     accuracy                           0.87        38
#    macro avg       0.86      0.87      0.86        38
# weighted avg       0.87      0.87      0.87        38

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn = knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.9736842105263158
# [[16  0  0]
#  [ 1 13  0]
#  [ 0  0  8]]
#               precision    recall  f1-score   support
#
#            1       0.94      1.00      0.97        16
#            2       1.00      0.93      0.96        14
#            3       1.00      1.00      1.00         8
#
#     accuracy                           0.97        38
#    macro avg       0.98      0.98      0.98        38
# weighted avg       0.98      0.97      0.97        38

# %%
def svmkernel(ker):
    svc = SVC(kernel = ker)
    svc.fit(x_train,y_train)
    svc.score(x_train,y_train)
    predsvc = svc.predict(x_test)
    print(accuracy_score(y_test,predsvc))
    print(confusion_matrix(y_test,predsvc))
    print(classification_report(y_test,predsvc))

# %%
svmkernel('rbf')
# Out:
# 1.0
# [[16  0  0]
#  [ 0 14  0]
#  [ 0  0  8]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        14
#            3       1.00      1.00      1.00         8
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
svmkernel('poly')
# Out:
# 0.9473684210526315
# [[16  0  0]
#  [ 1 13  0]
#  [ 1  0  7]]
#               precision    recall  f1-score   support
#
#            1       0.89      1.00      0.94        16
#            2       1.00      0.93      0.96        14
#            3       1.00      0.88      0.93         8
#
#     accuracy                           0.95        38
#    macro avg       0.96      0.93      0.95        38
# weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(svc,"Wine_dataset_Project.pkl")
# Out:
# ['Wine_dataset_Project.pkl']
